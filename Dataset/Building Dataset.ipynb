# %%
import pandas as pd
import numpy as np
import matplotlib

# %%
data1 = pd.read_csv('1.txt', sep=",",)
data2 = pd.read_csv('2.txt', sep=",",)
data3 = pd.read_csv('3.txt', sep=",",)
data4 = pd.read_csv('4.txt', sep=",",)
data5 = pd.read_csv('5.txt', sep=",",)
data6 = pd.read_csv('6.txt', sep=",",)
data7 = pd.read_csv('7.txt', sep=",",)
data8 = pd.read_csv('8.txt', sep=",",)
data9 = pd.read_csv('9.txt', sep=",",)
data10 = pd.read_csv('10.txt', sep=",",)
data11 = pd.read_csv('11.txt', sep=",",)
data12 = pd.read_csv('12.txt', sep=",",)
# Out:
# C:\Users\shrey\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (13,14,29) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# C:\Users\shrey\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (15,17,18) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
data1.to_csv('option data.csv', mode='a', index=False, header=False)
data2.to_csv('option data.csv', mode='a', index=False, header=False)
data3.to_csv('option data.csv', mode='a', index=False, header=False)
data4.to_csv('option data.csv', mode='a', index=False, header=False)
data5.to_csv('option data.csv', mode='a', index=False, header=False)
data6.to_csv('option data.csv', mode='a', index=False, header=False)
data7.to_csv('option data.csv', mode='a', index=False, header=False)
data8.to_csv('option data.csv', mode='a', index=False, header=False)
data9.to_csv('option data.csv', mode='a', index=False, header=False)
data10.to_csv('option data.csv', mode='a', index=False, header=False)
data11.to_csv('option data.csv', mode='a', index=False, header=False)
data12.to_csv('option data.csv', mode='a', index=False, header=False)

# %%
df=pd.read_csv('option data.csv')
df
# Out:
# C:\Users\shrey\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (15,17,18,20,21,23) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#         [QUOTE_UNIXTIME]   [QUOTE_READTIME]  [QUOTE_DATE]  \
# 0             1514926800   2018-01-02 16:00    2018-01-02
# 1             1514926800   2018-01-02 16:00    2018-01-02
# 2             1514926800   2018-01-02 16:00    2018-01-02
# 3             1514926800   2018-01-02 16:00    2018-01-02
# 4             1514926800   2018-01-02 16:00    2018-01-02
# ...                  ...                ...           ...
# 380135        1577826000   2019-12-31 16:00    2019-12-31
# 380136        1577826000   2019-12-31 16:00    2019-12-31
# 380137        1577826000   2019-12-31 16:00    2019-12-31
# 380138        1577826000   2019-12-31 16:00    2019-12-31
# 380139        1577826000   2019-12-31 16:00    2019-12-31
#
# ...
