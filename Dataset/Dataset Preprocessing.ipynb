# %%
import pandas as pd
import numpy as np
import matplotlib

# %%
df = pd.read_csv("option data.csv")
df
# Out:
# C:\Users\shrey\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (15,17,18,20,21,23) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#         [QUOTE_UNIXTIME]   [QUOTE_READTIME]  [QUOTE_DATE]  \
# 0             1514926800   2018-01-02 16:00    2018-01-02
# 1             1514926800   2018-01-02 16:00    2018-01-02
# 2             1514926800   2018-01-02 16:00    2018-01-02
# 3             1514926800   2018-01-02 16:00    2018-01-02
# 4             1514926800   2018-01-02 16:00    2018-01-02
# ...                  ...                ...           ...
# 380135        1577826000   2019-12-31 16:00    2019-12-31
# 380136        1577826000   2019-12-31 16:00    2019-12-31
# 380137        1577826000   2019-12-31 16:00    2019-12-31
# 380138        1577826000   2019-12-31 16:00    2019-12-31
# 380139        1577826000   2019-12-31 16:00    2019-12-31
#
# ...

# %%
df_copy = pd.DataFrame.copy(df)
df_copy
# Out:
#         [QUOTE_UNIXTIME]   [QUOTE_READTIME]  [QUOTE_DATE]  \
# 0             1514926800   2018-01-02 16:00    2018-01-02
# 1             1514926800   2018-01-02 16:00    2018-01-02
# 2             1514926800   2018-01-02 16:00    2018-01-02
# 3             1514926800   2018-01-02 16:00    2018-01-02
# 4             1514926800   2018-01-02 16:00    2018-01-02
# ...                  ...                ...           ...
# 380135        1577826000   2019-12-31 16:00    2019-12-31
# 380136        1577826000   2019-12-31 16:00    2019-12-31
# 380137        1577826000   2019-12-31 16:00    2019-12-31
# 380138        1577826000   2019-12-31 16:00    2019-12-31
# 380139        1577826000   2019-12-31 16:00    2019-12-31
#
#          [QUOTE_TIME_HOURS]   [UNDERLYING_LAST]  [EXPIRE_DATE]  \
# 0                      16.0              172.17     2018-01-05
# 1                      16.0              172.17     2018-01-05
# 2                      16.0              172.17     2018-01-05
# ...

# %%
df_copy=df_copy.drop(['[QUOTE_UNIXTIME]', ' [QUOTE_READTIME]', ' [QUOTE_TIME_HOURS]', ' [QUOTE_TIME_HOURS]', ' [EXPIRE_UNIX]', ' [C_SIZE]', ' [P_SIZE]', ' [STRIKE_DISTANCE_PCT]', ' [STRIKE_DISTANCE]'], axis = 1)
df_copy
# Out:
#         [QUOTE_DATE]   [UNDERLYING_LAST]  [EXPIRE_DATE]   [DTE]   [C_DELTA]  \
# 0         2018-01-02              172.17     2018-01-05     3.0     1.00000
# 1         2018-01-02              172.17     2018-01-05     3.0     1.00000
# 2         2018-01-02              172.17     2018-01-05     3.0     0.93296
# 3         2018-01-02              172.17     2018-01-05     3.0     1.00000
# 4         2018-01-02              172.17     2018-01-05     3.0     1.00000
# ...              ...                 ...            ...     ...         ...
# 380135    2019-12-31              293.20     2022-01-21   752.0     0.10801
# 380136    2019-12-31              293.20     2022-01-21   752.0     0.09483
# 380137    2019-12-31              293.20     2022-01-21   752.0     0.08492
# 380138    2019-12-31              293.20     2022-01-21   752.0     0.07622
# 380139    2019-12-31              293.20     2022-01-21   752.0     0.07809
#
# ...

# %%
df_copy.to_csv('final dataset.csv', mode='a', index=False, header=True)

# %%
df=pd.read_csv('final dataset.csv')
df
# Out:
# C:\Users\shrey\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (11,12,13,15,16,17) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#         [QUOTE_DATE]   [UNDERLYING_LAST]  [EXPIRE_DATE]   [DTE]   [C_DELTA]  \
# 0         2018-01-02              172.17     2018-01-05     3.0     1.00000
# 1         2018-01-02              172.17     2018-01-05     3.0     1.00000
# 2         2018-01-02              172.17     2018-01-05     3.0     0.93296
# 3         2018-01-02              172.17     2018-01-05     3.0     1.00000
# 4         2018-01-02              172.17     2018-01-05     3.0     1.00000
# ...              ...                 ...            ...     ...         ...
# 380135    2019-12-31              293.20     2022-01-21   752.0     0.10801
# 380136    2019-12-31              293.20     2022-01-21   752.0     0.09483
# ...

# %%
df_call=pd.DataFrame.copy(df)
df_call
# Out:
#         [QUOTE_DATE]   [UNDERLYING_LAST]  [EXPIRE_DATE]   [DTE]   [C_DELTA]  \
# 0         2018-01-02              172.17     2018-01-05     3.0     1.00000
# 1         2018-01-02              172.17     2018-01-05     3.0     1.00000
# 2         2018-01-02              172.17     2018-01-05     3.0     0.93296
# 3         2018-01-02              172.17     2018-01-05     3.0     1.00000
# 4         2018-01-02              172.17     2018-01-05     3.0     1.00000
# ...              ...                 ...            ...     ...         ...
# 380135    2019-12-31              293.20     2022-01-21   752.0     0.10801
# 380136    2019-12-31              293.20     2022-01-21   752.0     0.09483
# 380137    2019-12-31              293.20     2022-01-21   752.0     0.08492
# 380138    2019-12-31              293.20     2022-01-21   752.0     0.07622
# 380139    2019-12-31              293.20     2022-01-21   752.0     0.07809
#
# ...

# %%
df_call=df_call.drop([' [P_BID]', ' [P_ASK]', ' [P_LAST]', ' [P_DELTA]', ' [P_GAMMA]', ' [P_VEGA]', ' [P_THETA]', ' [P_RHO]', ' [P_IV]', ' [P_VOLUME]'], axis = 1)
df_call
# Out:
#         [QUOTE_DATE]   [UNDERLYING_LAST]  [EXPIRE_DATE]   [DTE]   [C_DELTA]  \
# 0         2018-01-02              172.17     2018-01-05     3.0     1.00000
# 1         2018-01-02              172.17     2018-01-05     3.0     1.00000
# 2         2018-01-02              172.17     2018-01-05     3.0     0.93296
# 3         2018-01-02              172.17     2018-01-05     3.0     1.00000
# 4         2018-01-02              172.17     2018-01-05     3.0     1.00000
# ...              ...                 ...            ...     ...         ...
# 380135    2019-12-31              293.20     2022-01-21   752.0     0.10801
# 380136    2019-12-31              293.20     2022-01-21   752.0     0.09483
# 380137    2019-12-31              293.20     2022-01-21   752.0     0.08492
# 380138    2019-12-31              293.20     2022-01-21   752.0     0.07622
# 380139    2019-12-31              293.20     2022-01-21   752.0     0.07809
#
# ...

# %%
df_call.to_csv('final dataset call.csv', mode='a', index=False, header=True)

# %%
df_put=pd.DataFrame.copy(df)
df_put
# Out:
#         [QUOTE_DATE]   [UNDERLYING_LAST]  [EXPIRE_DATE]   [DTE]   [C_DELTA]  \
# 0         2018-01-02              172.17     2018-01-05     3.0     1.00000
# 1         2018-01-02              172.17     2018-01-05     3.0     1.00000
# 2         2018-01-02              172.17     2018-01-05     3.0     0.93296
# 3         2018-01-02              172.17     2018-01-05     3.0     1.00000
# 4         2018-01-02              172.17     2018-01-05     3.0     1.00000
# ...              ...                 ...            ...     ...         ...
# 380135    2019-12-31              293.20     2022-01-21   752.0     0.10801
# 380136    2019-12-31              293.20     2022-01-21   752.0     0.09483
# 380137    2019-12-31              293.20     2022-01-21   752.0     0.08492
# 380138    2019-12-31              293.20     2022-01-21   752.0     0.07622
# 380139    2019-12-31              293.20     2022-01-21   752.0     0.07809
#
# ...

# %%
df_put=df_put.drop([' [C_BID]', ' [C_ASK]', ' [C_LAST]', ' [C_DELTA]', ' [C_GAMMA]', ' [C_VEGA]', ' [C_THETA]', ' [C_RHO]', ' [C_IV]', ' [C_VOLUME]'], axis = 1)
df_put
# Out:
#         [QUOTE_DATE]   [UNDERLYING_LAST]  [EXPIRE_DATE]   [DTE]   [STRIKE]  \
# 0         2018-01-02              172.17     2018-01-05     3.0      125.0
# 1         2018-01-02              172.17     2018-01-05     3.0      130.0
# 2         2018-01-02              172.17     2018-01-05     3.0      135.0
# 3         2018-01-02              172.17     2018-01-05     3.0      140.0
# 4         2018-01-02              172.17     2018-01-05     3.0      144.0
# ...              ...                 ...            ...     ...        ...
# 380135    2019-12-31              293.20     2022-01-21   752.0      460.0
# 380136    2019-12-31              293.20     2022-01-21   752.0      470.0
# 380137    2019-12-31              293.20     2022-01-21   752.0      480.0
# 380138    2019-12-31              293.20     2022-01-21   752.0      490.0
# 380139    2019-12-31              293.20     2022-01-21   752.0      500.0
#
# ...

# %%
df_put.to_csv('final dataset put.csv', mode='a', index=False, header=True)
