# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import sklearn
from sklearn.metrics import mean_absolute_error, mean_squared_error
import tensorflow as tf
import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.losses import kullback_leibler_divergence

# %%
df_c=pd.read_csv('FINAL CALL DATA.csv')
df_c
# Out:
#          [UNDERLYING_LAST]     [DTE]   [C_DELTA]   [C_GAMMA]   [C_VEGA]  \
# 0                   172.17  0.008219     0.94168     0.00094    0.01792
# 1                   172.17  0.008219     0.94263     0.00186    0.01850
# 2                   172.17  0.008219     0.94503     0.00174    0.01738
# 3                   172.17  0.008219     0.94318     0.00412    0.01893
# 4                   172.17  0.008219     0.94856     0.00337    0.01729
# ...                    ...       ...         ...         ...        ...
# 277006              293.20  2.060274     0.18480     0.00260    1.12195
# 277007              293.20  2.060274     0.15494     0.00231    0.99964
# 277008              293.20  2.060274     0.08492     0.00159    0.65873
# 277009              293.20  2.060274     0.07622     0.00146    0.60341
# 277010              293.20  2.060274     0.07809     0.00140    0.61815
#
#          [C_THETA]   [C_RHO]   [C_IV]   [C_LAST]   [STRIKE]    Call_BS
# 0         -0.03468   0.00227  0.84394      23.00      147.0  25.282476
# 1         -0.06046   0.00321  0.74618      21.75      150.0  22.279862
# 2         -0.03516   0.00189  0.64277      17.55      152.5  19.761204
# 3         -0.08519   0.00381  0.58444      17.17      155.0  17.274256
# 4         -0.03541   0.00301  0.47237      13.60      157.5  14.746163
# ...            ...       ...      ...        ...        ...        ...
# 277006    -0.01733   0.91873  0.24551      10.95      420.0  12.220778
# 277007    -0.01550   0.77516  0.24797       6.00      440.0  10.053164
# 277008    -0.00965   0.44507  0.23212       3.49      480.0   5.019698
# 277009    -0.00848   0.39812  0.23210       2.85      490.0   4.428689
# 277010    -0.00938   0.40820  0.24195       3.40      500.0   4.649710
#
# [277011 rows x 11 columns]

# %%
n = len(df_c)
n_train =  (int)(0.7 * n)
print(n_train)
# Out:
# 193907

# %%
train = df_c[0:n_train]
X_train = train[[' [UNDERLYING_LAST]', ' [DTE]', ' [STRIKE]', ' [C_IV]']].values
y_train = train[' [C_LAST]'].values

# %%
test = df_c[n_train+1:n]
X_test = test[[' [UNDERLYING_LAST]', ' [DTE]', ' [STRIKE]', ' [C_IV]']].values
y_test = test[' [C_LAST]'].values

# %%
from keras.layers import Activation, LeakyReLU, BatchNormalization
from keras.callbacks import EarlyStopping, TensorBoard

# %%
model = Sequential()

model.add(Dense(64, input_dim=X_train.shape[1]))
model.add(BatchNormalization())
model.add(LeakyReLU())
model.add(Dropout(0.25))

model.add(Dense(128, activation='elu'))
model.add(BatchNormalization())
model.add(Dropout(0.25))

model.add(Dense(128, activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.25))

model.add(Dense(64, activation='elu'))
model.add(BatchNormalization())
model.add(Dropout(0.25))

model.add(Dense(32, activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.25))

model.add(Dense(1))
model.add(LeakyReLU())
          
model.compile(loss=kullback_leibler_divergence, optimizer='adam', metrics=['mean_absolute_error', 'mean_squared_error'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 64)                320
# _________________________________________________________________
# batch_normalization (BatchNo (None, 64)                256
# _________________________________________________________________
# leaky_re_lu (LeakyReLU)      (None, 64)                0
# _________________________________________________________________
# dropout (Dropout)            (None, 64)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               8320
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 128)               512
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               16512
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 128)               512
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 64)                8256
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 64)                256
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_4 (Dense)              (None, 32)                2080
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 32)                128
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 33
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 1)                 0
# =================================================================
# Total params: 37,185
# Trainable params: 36,353
# Non-trainable params: 832
# _________________________________________________________________

# %%
callback_es = EarlyStopping(monitor='val_loss', patience=5, verbose=2, restore_best_weights=True)

# %%
model.fit(X_train, y_train, batch_size=64, epochs=30, verbose=2, 
          callbacks=[callback_es], validation_data=(X_test, y_test))
# Out:
# Epoch 1/30
# 3030/3030 - 41s - loss: 7.5836 - mean_absolute_error: 7.5836 - mean_squared_error: 211.9481 - val_loss: 6.5194 - val_mean_absolute_error: 6.5194 - val_mean_squared_error: 67.6990
# Epoch 2/30
# 3030/3030 - 33s - loss: 5.5414 - mean_absolute_error: 5.5414 - mean_squared_error: 100.6334 - val_loss: 4.2528 - val_mean_absolute_error: 4.2528 - val_mean_squared_error: 38.4020
# Epoch 3/30
# 3030/3030 - 34s - loss: 5.4481 - mean_absolute_error: 5.4481 - mean_squared_error: 99.5807 - val_loss: 6.9185 - val_mean_absolute_error: 6.9185 - val_mean_squared_error: 84.6270
# Epoch 4/30
# 3030/3030 - 34s - loss: 5.3256 - mean_absolute_error: 5.3256 - mean_squared_error: 95.4138 - val_loss: 3.5057 - val_mean_absolute_error: 3.5057 - val_mean_squared_error: 32.9145
# Epoch 5/30
# 3030/3030 - 34s - loss: 5.3148 - mean_absolute_error: 5.3148 - mean_squared_error: 95.2518 - val_loss: 3.2239 - val_mean_absolute_error: 3.2239 - val_mean_squared_error: 32.5912
# Epoch 6/30
# 3030/3030 - 33s - loss: 5.2684 - mean_absolute_error: 5.2684 - mean_squared_error: 94.4507 - val_loss: 4.3549 - val_mean_absolute_error: 4.3549 - val_mean_squared_error: 37.6158
# Epoch 7/30
# 3030/3030 - 32s - loss: 5.2285 - mean_absolute_error: 5.2285 - mean_squared_error: 92.9906 - val_loss: 4.7115 - val_mean_absolute_error: 4.7115 - val_mean_squared_error: 37.5405
# Epoch 8/30
# 3030/3030 - 32s - loss: 5.1928 - mean_absolute_error: 5.1928 - mean_squared_error: 92.4272 - val_loss: 2.0259 - val_mean_absolute_error: 2.0259 - val_mean_squared_error: 14.0497
# Epoch 9/30
# 3030/3030 - 34s - loss: 5.1760 - mean_absolute_error: 5.1760 - mean_squared_error: 91.3658 - val_loss: 2.2000 - val_mean_absolute_error: 2.2000 - val_mean_squared_error: 14.0030
# Epoch 10/30
# 3030/3030 - 33s - loss: 5.1254 - mean_absolute_error: 5.1254 - mean_squared_error: 90.0275 - val_loss: 2.6599 - val_mean_absolute_error: 2.6599 - val_mean_squared_error: 17.7357
# Epoch 11/30
# 3030/3030 - 33s - loss: 5.1376 - mean_absolute_error: 5.1376 - mean_squared_error: 90.9364 - val_loss: 3.8306 - val_mean_absolute_error: 3.8306 - val_mean_squared_error: 36.9239
# Epoch 12/30
# 3030/3030 - 34s - loss: 5.1008 - mean_absolute_error: 5.1008 - mean_squared_error: 88.9212 - val_loss: 3.5723 - val_mean_absolute_error: 3.5723 - val_mean_squared_error: 30.6293
# Epoch 13/30
# 3030/3030 - 33s - loss: 5.0827 - mean_absolute_error: 5.0827 - mean_squared_error: 87.5125 - val_loss: 5.3565 - val_mean_absolute_error: 5.3565 - val_mean_squared_error: 61.5897
# Restoring model weights from the end of the best epoch.
# Epoch 00013: early stopping

# %%
y_train_pred = model.predict(X_train)

# %%
y_train_pred=np.ravel(y_train_pred)

# %%
train['Call_MLP']=y_train_pred
train
# Out:
# <ipython-input-15-7182497b72b8>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train['Call_MLP']=y_train_pred
#          [UNDERLYING_LAST]     [DTE]   [C_DELTA]   [C_GAMMA]   [C_VEGA]  \
# 0                   172.17  0.008219     0.94168     0.00094    0.01792
# 1                   172.17  0.008219     0.94263     0.00186    0.01850
# 2                   172.17  0.008219     0.94503     0.00174    0.01738
# 3                   172.17  0.008219     0.94318     0.00412    0.01893
# 4                   172.17  0.008219     0.94856     0.00337    0.01729
# ...                    ...       ...         ...         ...        ...
# 193902              179.02  1.649425     0.65827     0.00573    0.84465
# 193903              179.02  1.649425     0.62671     0.00588    0.87102
# 193904              179.02  1.649425     0.59577     0.00612    0.89144
# 193905              179.02  1.649425     0.56406     0.00628    0.90553
# 193906              179.02  1.649425     0.53224     0.00636    0.91475
#
#          [C_THETA]   [C_RHO]   [C_IV]   [C_LAST]   [STRIKE]    Call_BS  \
# 0         -0.03468   0.00227  0.84394      23.00      147.0  25.282476
# 1         -0.06046   0.00321  0.74618      21.75      150.0  22.279862
# 2         -0.03516   0.00189  0.64277      17.55      152.5  19.761204
# 3         -0.08519   0.00381  0.58444      17.17      155.0  17.274256
# 4         -0.03541   0.00301  0.47237      13.60      157.5  14.746163
# ...            ...       ...      ...        ...        ...        ...
# 193902    -0.02014   1.41244  0.28033      32.60      165.0  35.369786
# 193903    -0.02038   1.36556  0.27820      30.90      170.0  32.577601
# 193904    -0.02070   1.31353  0.27681      27.13      175.0  29.994880
# 193905    -0.02039   1.25991  0.27454      24.73      180.0  27.482092
# 193906    -0.02076   1.20376  0.27158      22.57      185.0  25.049588
#
#          Call_MLP
# 0       26.166594
# 1       23.642908
# 2       21.301966
# 3       18.877253
# 4       15.861603
# ...           ...
# 193902  31.065552
# 193903  28.169470
# 193904  25.709045
# 193905  23.648935
# 193906  21.394878
#
# [193907 rows x 12 columns]

# %%
y_true=train[' [C_LAST]']
y_pred=train['Call_MLP']
print('MAE = ', mean_absolute_error(y_true, y_pred))
print('MSE = ', mean_squared_error(y_true, y_pred))
print('RMSE = ', mean_squared_error(y_true, y_pred, squared=False))
# Out:
# MAE =  1.7254417414750058
# MSE =  17.465845558843647
# RMSE =  4.179215902396483

# %%
plt.scatter(y_true, y_pred,color='black',linewidth=0.2,alpha=0.5, s=0.5)
plt.xlabel('Actual Price')
plt.ylabel('Calculated Price') 
plt.show()

# %%
stats = dict()
stats['diff'] = y_true - y_pred
plt.hist(stats['diff'], bins=60,edgecolor='black',color='white')
plt.xlabel('Difference')
plt.ylabel('Density')
plt.show()

# %%
y_test_pred=model.predict(X_test)

# %%
y_test_pred=np.ravel(y_test_pred)

# %%
test['Call_MLP']=y_test_pred
test
# Out:
# <ipython-input-21-9bcb9758f35d>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['Call_MLP']=y_test_pred
#          [UNDERLYING_LAST]     [DTE]   [C_DELTA]   [C_GAMMA]   [C_VEGA]  \
# 193908              179.02  1.649425     0.47056     0.00645    0.91520
# 193909              179.02  1.649425     0.44009     0.00641    0.90725
# 193910              179.02  1.649425     0.41070     0.00633    0.89419
# 193911              179.02  1.649425     0.38230     0.00629    0.87701
# 193912              179.02  1.649425     0.35522     0.00610    0.85580
# ...                    ...       ...         ...         ...        ...
# 277006              293.20  2.060274     0.18480     0.00260    1.12195
# 277007              293.20  2.060274     0.15494     0.00231    0.99964
# 277008              293.20  2.060274     0.08492     0.00159    0.65873
# 277009              293.20  2.060274     0.07622     0.00146    0.60341
# 277010              293.20  2.060274     0.07809     0.00140    0.61815
#
#          [C_THETA]   [C_RHO]   [C_IV]   [C_LAST]   [STRIKE]    Call_BS  \
# 193908    -0.02033   1.08559  0.26887      18.55      195.0  20.895615
# 193909    -0.02019   1.02520  0.26711      16.70      200.0  18.986668
# 193910    -0.01936   0.96454  0.26497      14.95      205.0  17.174165
# 193911    -0.01918   0.90546  0.26478      13.60      210.0  15.664548
# 193912    -0.01888   0.84713  0.26322      12.55      215.0  14.150901
# ...            ...       ...      ...        ...        ...        ...
# 277006    -0.01733   0.91873  0.24551      10.95      420.0  12.220778
# 277007    -0.01550   0.77516  0.24797       6.00      440.0  10.053164
# 277008    -0.00965   0.44507  0.23212       3.49      480.0   5.019698
# 277009    -0.00848   0.39812  0.23210       2.85      490.0   4.428689
# 277010    -0.00938   0.40820  0.24195       3.40      500.0   4.649710
#
#          Call_MLP
# 193908  16.759176
# 193909  14.750557
# 193910  13.128057
# 193911  11.697142
# 193912  10.438192
# ...           ...
# 277006   8.622215
# 277007   6.227463
# 277008   3.561239
# 277009   3.010648
# 277010   2.520973
#
# [83103 rows x 12 columns]

# %%
y_true=test[' [C_LAST]']
y_pred=test['Call_MLP']
print('MAE = ', mean_absolute_error(y_true, y_pred))
print('MSE = ', mean_squared_error(y_true, y_pred))
print('RMSE = ', mean_squared_error(y_true, y_pred, squared=False))
# Out:
# MAE =  2.025893204966135
# MSE =  14.04970445766198
# RMSE =  3.7482935394205694

# %%
# model = keras.models.load_model('MLP_Call.h5')

# %%
plt.scatter(y_true, y_pred,color='black',linewidth=0.2,alpha=0.5, s=0.5)
plt.xlabel('Actual Price')
plt.ylabel('Calculated Price') 
plt.show()

# %%
stats = dict()
stats['diff'] = y_true - y_pred
plt.hist(stats['diff'], bins=60,edgecolor='black',color='white')
plt.xlabel('Difference')
plt.ylabel('Density')
plt.show()

# %%
# train.to_csv('MLP CALL train FINAL Results.csv', mode='a', index=False, header=True)

# %%
# test.to_csv('MLP CALL test FINAL Results.csv', mode='a', index=False, header=True)

# %%
# model.save('MLP_Call.h5')
